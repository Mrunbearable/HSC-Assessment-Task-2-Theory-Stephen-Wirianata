# %%
def validate_age(age_input):
    
    try:
        age = int(age_input)
        if 0 <= age <= 120:
            return age
        else:
            raise ValueError("Age must be between 0 and 120.")
    except ValueError as e:
        print(f"Invalid input: {e}")
        return None

while True:
    user_input = input("Enter your age: ")
    age_input = validate_age(user_input)
    if age_input is not None:
        print(f"Your age is: {age_input}")
        break
    else:
        print("Please enter a valid age.")
# Out:
# Invalid input: invalid literal for int() with base 10: 'dewaewdwa'
# Please enter a valid age.
# Invalid input: invalid literal for int() with base 10: 'wadae'
# Please enter a valid age.
# Your age is: 34

# %%
username = input("Enter your username: ")
print(f"Welcome, {username}!")
# Out:
# Welcome, boof!
